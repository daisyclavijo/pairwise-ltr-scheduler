# %% [markdown]
# # ProD-M + PARS — Real Pipeline (Llama 3.1 8B)
#
# 1. Set GPU runtime (T4 or better)
# 2. Set `HF_TOKEN` in the cell below
# 3. Run all cells

# %%
import os
os.environ["HF_TOKEN"] = "hf_YOUR_TOKEN_HERE"  # <-- paste your token

# !git clone https://github.com/YOUR_USERNAME/pairwise-ltr-scheduler.git
# %cd pairwise-ltr-scheduler
# !pip install -q -r requirements.txt
# !python scripts/check_setup.py

# %%
# Full pipeline: GSM8K + MBPP + LMSYS + LongBench -> Llama labels -> ProD-M -> PARS
# !python scripts/run_pipeline.py --dataset all --limit 400 --device cuda

# %%
# Evaluate schedulers on real labels
# !python scripts/run_simulation.py --compare-all --device cuda
